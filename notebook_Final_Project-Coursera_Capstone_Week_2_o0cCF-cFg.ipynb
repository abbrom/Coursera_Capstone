# %% [markdown]
# # Import Python Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

from bs4 import BeautifulSoup
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.8.28-0                   --> 2019.9.11-hecc5488_0 conda-forge
#     certifi:         2019.9.11-py36_0              --> 2019.9.11-py36_0     conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.1.1d-h7b6447c_2             --> 1.1.1c-h516909a_0    conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# ca-certificates-2019 | 144 KB    | ##################################### | 100%
# openssl-1.1.1c       | 2.1 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-3.2.0               |           py36_0         770 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         868 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  3.2.0-py36_0 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-3.2.0         | 770 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# # Connect to the Foursquare API

# %%
CLIENT_ID = 'ZKWH10LSBTKPCOFAXZ3VB5SF1310UBUMSTMYFBAAP34OJCWC' # your Foursquare ID
CLIENT_SECRET = 'XBURRWEJJNBPOUE1MDWWRYRIZPRFIWC50A4FIUO1QNQOSROC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZKWH10LSBTKPCOFAXZ3VB5SF1310UBUMSTMYFBAAP34OJCWC
# CLIENT_SECRET:XBURRWEJJNBPOUE1MDWWRYRIZPRFIWC50A4FIUO1QNQOSROC

# %% [markdown]
# # Use Geolocator to get the Latitude and Longitude of Johannesburg

# %%
address = 'Braamfontein, South Africa'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -26.1923213 28.0361983

# %% [markdown]
# # Search for Coffee in a given radius

# %%
search_query = ''
radius = 500
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
#  .... OK!
# {'meta': {'code': 200, 'requestId': '5dae020d492822002d77a9d0'},
#  'response': {'venues': [{'id': '5147a0f8e4b0a319f5300d1e',
#     'name': 'Steers Braamfontein',
#     'location': {'address': 'Jorrisen Street',
#      'lat': -26.192902718815258,
#      'lng': 28.03669676376044,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192902718815258,
#        'lng': 28.03669676376044}],
#      'distance': 81,
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Jorrisen Street', 'JHB', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e170754b61c2903bf0690e1',
#     'name': 'JD Group Head Office',
#     'location': {'address': '27 Stiemens Street',
#      'lat': -26.191903211556145,
#      'lng': 28.036170759341008,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191903211556145,
#        'lng': 28.036170759341008}],
#      'distance': 46,
#      'postalCode': '2017',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['27 Stiemens Street',
#       'EGoli',
#       '2017',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4c93463efc9a224b84fbf8f1',
#     'name': "Nando's",
#     'location': {'address': '30 Melle Street',
#      'lat': -26.19289137,
#      'lng': 28.03616438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19289137,
#        'lng': 28.03616438}],
#      'distance': 63,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['30 Melle Street',
#       'Braamfontein',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4def73e84765ae376e57713a',
#       'name': 'Portuguese Restaurant',
#       'pluralName': 'Portuguese Restaurants',
#       'shortName': 'Portuguese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '553105539'},
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51c03298498e91717cb6965f',
#     'name': 'Fnb braamfontein',
#     'location': {'lat': -26.192697242953585,
#      'lng': 28.036542393060337,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192697242953585,
#        'lng': 28.036542393060337}],
#      'distance': 54,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4dbaa29a81548ee14d7ddb35',
#     'name': 'First National Bank',
#     'location': {'address': 'Fnb 3',
#      'lat': -26.192859358781185,
#      'lng': 28.03658813254108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192859358781185,
#        'lng': 28.03658813254108}],
#      'distance': 71,
#      'postalCode': '2147',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Fnb 3',
#       'Braamfontein',
#       '2147',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d746dc39b28224b1dddd50f',
#     'name': 'Absa Bank North City House Braamfontein',
#     'location': {'lat': -26.191963070366253,
#      'lng': 28.03633656525069,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191963070366253,
#        'lng': 28.03633656525069}],
#      'distance': 42,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d01e7686b0c236af79aaba2',
#     'name': 'Devonshire Hotel - Braamfontein',
#     'location': {'address': '49 Jorissen St',
#      'crossStreet': 'Melle St',
#      'lat': -26.192708967540018,
#      'lng': 28.036050692895625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192708967540018,
#        'lng': 28.036050692895625}],
#      'distance': 45,
#      'postalCode': '2017',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['49 Jorissen St (Melle St)',
#       'EGoli',
#       '2017',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4c921fbc7f3b8cfa5d52a21e',
#     'name': 'Médecins Sans Frontières (MSF) - South Africa',
#     'location': {'address': '49 Jorissen St., 3rd Floor',
#      'crossStreet': 'Melle St.',
#      'lat': -26.192847919994563,
#      'lng': 28.036354670459858,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192847919994563,
#        'lng': 28.036354670459858}],
#      'distance': 60,
#      'postalCode': '2017',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['49 Jorissen St., 3rd Floor (Melle St.)',
#       'EGoli',
#       '2017',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4c0893f7009a0f47e068e6bf',
#     'name': 'JD House',
#     'location': {'lat': -26.19195432570274,
#      'lng': 28.03620093750918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19195432570274,
#        'lng': 28.03620093750918}],
#      'distance': 40,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d1dca18dd6a236a5f772038',
#     'name': 'Debonairs Pizza',
#     'location': {'address': 'Shop 1 Jorbic House, Cnr Biccard And Jorrison Street, Braamfontein',
#      'crossStreet': 'Jorissen St',
#      'lat': -26.192520325742947,
#      'lng': 28.036788163634924,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192520325742947,
#        'lng': 28.036788163634924}],
#      'distance': 62,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Shop 1 Jorbic House, Cnr Biccard And Jorrison Street, Braamfontein (Jorissen St)',
#       'EGoli',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5b50cf5e3260db001c36dd01',
#     'name': 'Artivist',
#     'location': {'address': '7 Reserve Street',
#      'lat': -26.193171,
#      'lng': 28.036803,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193171,
#        'lng': 28.036803}],
#      'distance': 112,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['7 Reserve Street',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '533130d011d271112c08344c',
#     'name': 'Clicks',
#     'location': {'address': 'Jorrissen Str',
#      'lat': -26.19222697704686,
#      'lng': 28.036113584853368,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19222697704686,
#        'lng': 28.036113584853368}],
#      'distance': 13,
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Jorrissen Str',
#       'Braamfontein',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '582b198b26d44f0d228af768',
#     'name': 'Virgin Active Red Gym Braamfontein',
#     'location': {'address': 'Jorrisen Street',
#      'lat': -26.193058,
#      'lng': 28.035387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193058,
#        'lng': 28.035387}],
#      'distance': 115,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'Johannesburg',
#      'state': 'Gaugeng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Jorrisen Street',
#       'Johannesburg',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4c6382cf58810f474e0f0a1e',
#     'name': "Nino's Braamfontein",
#     'location': {'lat': -26.191708781193977,
#      'lng': 28.03564251120332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191708781193977,
#        'lng': 28.03564251120332}],
#      'distance': 87,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4f732cdee4b00743451232f9',
#     'name': 'Liberty Gym',
#     'location': {'lat': -26.19104942971893,
#      'lng': 28.03514161573696,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19104942971893,
#        'lng': 28.03514161573696}],
#      'distance': 176,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e364a1cd4c063434836ecf1',
#     'name': 'Orion',
#     'location': {'address': '49 Jorissen',
#      'crossStreet': 'Melle',
#      'lat': -26.1927561836301,
#      'lng': 28.036573071967577,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1927561836301,
#        'lng': 28.036573071967577}],
#      'distance': 61,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['49 Jorissen (Melle)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5200c97c498e5f4767c778e9',
#     'name': 'Nedbank',
#     'location': {'address': '96 Jorissen Street, Braamfontein Nedbank, Johannesburg',
#      'lat': -26.193222045898438,
#      'lng': 28.031766891479492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193222045898438,
#        'lng': 28.031766891479492}],
#      'distance': 453,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['96 Jorissen Street, Braamfontein Nedbank, Johannesburg',
#       'Braamfontein',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '536e8401498e080bd9bee363',
#     'name': 'And Club',
#     'location': {'lat': -26.19210178991824,
#      'lng': 28.034775696568722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19210178991824,
#        'lng': 28.034775696568722}],
#      'distance': 144,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '57d27c3c498ec65fd817d109',
#     'name': 'Once in Joburg',
#     'location': {'address': '90 De Korte Street',
#      'lat': -26.193871730809743,
#      'lng': 28.03624931206623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193871730809743,
#        'lng': 28.03624931206623}],
#      'distance': 172,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['90 De Korte Street',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '58a66e0619b1ad18d7d89f9e',
#     'name': 'GALATA BAKERY&COFFEE',
#     'location': {'address': '87 Juta street Braamfontein',
#      'lat': -26.193957003238783,
#      'lng': 28.03613924076584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193957003238783,
#        'lng': 28.03613924076584}],
#      'distance': 182,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['87 Juta street Braamfontein',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '52fcfd93498e5ba0aeb20785',
#     'name': 'mochachos chicken villages',
#     'location': {'lat': -26.192287816766783,
#      'lng': 28.035953496189688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192287816766783,
#        'lng': 28.035953496189688}],
#      'distance': 24,
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Braamfontein', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1c1941735',
#       'name': 'Mexican Restaurant',
#       'pluralName': 'Mexican Restaurants',
#       'shortName': 'Mexican',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '59845ae6b9a5a866d56cf9b9',
#     'name': 'Spanners',
#     'location': {'lat': -26.191561,
#      'lng': 28.035482,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191561,
#        'lng': 28.035482}],
#      'distance': 110,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', '2001', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e6746b8a8098026753e00cc',
#     'name': 'Jormelle',
#     'location': {'address': 'Melle Street',
#      'crossStreet': 'Jorrison',
#      'lat': -26.1923625,
#      'lng': 28.0361847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1923625,
#        'lng': 28.0361847}],
#      'distance': 4,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Melle Street (Jorrison)',
#       'Braamfontein, Johannesburg',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '52a1af4811d2606567ab62cb',
#     'name': 'R Janas TakeAway',
#     'location': {'lat': -26.19365692138672,
#      'lng': 28.036191940307617,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19365692138672,
#        'lng': 28.036191940307617}],
#      'distance': 148,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d46b29614aa8cfab25d7f3d',
#     'name': "Pick 'n Pay",
#     'location': {'address': 'Braamfontein Centre',
#      'crossStreet': 'Cnr. Jorissen & Bertha St. Braamfontein',
#      'lat': -26.192794878836263,
#      'lng': 28.03442121165301,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192794878836263,
#        'lng': 28.03442121165301}],
#      'distance': 185,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'Johanessburg',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Braamfontein Centre (Cnr. Jorissen & Bertha St. Braamfontein)',
#       'Johanessburg',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '53525cb111d2993499d8f9e2',
#     'name': 'Mickeys',
#     'location': {'lat': -26.192218310915507,
#      'lng': 28.035753385156408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192218310915507,
#        'lng': 28.035753385156408}],
#      'distance': 45,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e39395c6284250071bae2c9',
#     'name': 'KFC',
#     'location': {'lat': -26.19338460735376,
#      'lng': 28.03697829689719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19338460735376,
#        'lng': 28.03697829689719}],
#      'distance': 141,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4b8975c6f964a520543832e3',
#     'name': 'The Alexander Theatre',
#     'location': {'address': '36 Stiemens St. Braamfontein',
#      'crossStreet': 'btwn De Beer & Melle St.',
#      'lat': -26.192280862969564,
#      'lng': 28.035004689322285,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192280862969564,
#        'lng': 28.035004689322285}],
#      'distance': 119,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['36 Stiemens St. Braamfontein (btwn De Beer & Melle St.)',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '53c15e0f498ed6ec6b7968ce',
#     'name': '34 on Melle',
#     'location': {'lat': -26.192792011392836,
#      'lng': 28.035741950233387,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192792011392836,
#        'lng': 28.035741950233387}],
#      'distance': 69,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d47f79f847e6dcb3d5c99c4',
#     'name': 'Standard Bank (Braamfontein)',
#     'location': {'lat': -26.192947921103233,
#      'lng': 28.034740756315088,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192947921103233,
#        'lng': 28.034740756315088}],
#      'distance': 161,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10a951735',
#       'name': 'Bank',
#       'pluralName': 'Banks',
#       'shortName': 'Bank',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '513e055ae4b0a1e31e800665',
#     'name': 'South point',
#     'location': {'address': '20 melle street',
#      'lat': -26.192098911833362,
#      'lng': 28.035759102617646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192098911833362,
#        'lng': 28.035759102617646}],
#      'distance': 50,
#      'cc': 'ZA',
#      'city': 'Braamfontien',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['20 melle street',
#       'Braamfontien',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4c15bd0db7b9c9287673ad37',
#     'name': 'City Of Joburg revenue & customer service centre',
#     'location': {'lat': -26.19197153138223,
#      'lng': 28.03797174623594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19197153138223,
#        'lng': 28.03797174623594}],
#      'distance': 181,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e313e26aeb7d41efd926923',
#     'name': 'The Grove',
#     'location': {'lat': -26.193964,
#      'lng': 28.036086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193964,
#        'lng': 28.036086}],
#      'distance': 183,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51922092498e273e49c3a47a',
#     'name': "'86 Public",
#     'location': {'address': '86 Juta St.',
#      'crossStreet': 'Melle St.',
#      'lat': -26.19410081509326,
#      'lng': 28.03601101532084,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19410081509326,
#        'lng': 28.03601101532084}],
#      'distance': 198,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['86 Juta St. (Melle St.)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5d1e52c561bdc400239db35e',
#     'name': 'Untitled Basement',
#     'location': {'lat': -26.193005,
#      'lng': 28.036561,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193005,
#        'lng': 28.036561}],
#      'distance': 84,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', '2001', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4cea0e38e888f04db6574b6b',
#     'name': 'Absa Braamfontein, J D House',
#     'location': {'address': 'J D House',
#      'crossStreet': 'Stiemens Street',
#      'lat': -26.191825821403853,
#      'lng': 28.03738857153981,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191825821403853,
#        'lng': 28.03738857153981}],
#      'distance': 131,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['J D House (Stiemens Street)',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e0d94f0e4cd27fc7d26b104',
#     'name': 'Capitec Braamfontein',
#     'location': {'lat': -26.192667450594055,
#      'lng': 28.036508088442027,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192667450594055,
#        'lng': 28.036508088442027}],
#      'distance': 49,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5cd93e91535d6f002cdd0694',
#     'name': "Food Lover's Eatery Braamfontein",
#     'location': {'address': '19 Ameshoff Street',
#      'lat': -26.1905815,
#      'lng': 28.03736169999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1905815,
#        'lng': 28.03736169999999}],
#      'distance': 225,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['19 Ameshoff Street',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '546918313'},
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4fffbee0e4b0493bad1cb2be',
#     'name': 'Black Forest Bakery',
#     'location': {'address': '102 Juta street',
#      'crossStreet': 'Biccard',
#      'lat': -26.194069,
#      'lng': 28.037597,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194069,
#        'lng': 28.037597}],
#      'distance': 239,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['102 Juta street (Biccard)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4cad662155238cfae980b1fb',
#     'name': 'Wimpy',
#     'location': {'address': '39 Jorissen St, Braamfontein',
#      'lat': -26.19282549503993,
#      'lng': 28.035473749094397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19282549503993,
#        'lng': 28.035473749094397}],
#      'distance': 91,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['39 Jorissen St, Braamfontein',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d46d8011b62b1f733cb0ae3',
#     'name': "Mzitho's Kitchen",
#     'location': {'address': '8 Reserve St',
#      'crossStreet': 'btwn Jorrison & De Korte St',
#      'lat': -26.192931246512096,
#      'lng': 28.036599567409414,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192931246512096,
#        'lng': 28.036599567409414}],
#      'distance': 78,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['8 Reserve St (btwn Jorrison & De Korte St)',
#       'Braamfontein',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '55337a2a498edd66448157cf',
#     'name': 'Hillsong Johannesburg',
#     'location': {'address': 'The Alexander Theatre, 36 Stiemans Street',
#      'lat': -26.19230276524114,
#      'lng': 28.034901481368145,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19230276524114,
#        'lng': 28.034901481368145}],
#      'distance': 129,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['The Alexander Theatre, 36 Stiemans Street',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a32',
#       'name': 'Cultural Center',
#       'pluralName': 'Cultural Centers',
#       'shortName': 'Cultural Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5037d54de4b04a184c2a6e59',
#     'name': 'Puma Store Braamfontein',
#     'location': {'lat': -26.193486005285745,
#      'lng': 28.035707645459887,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193486005285745,
#        'lng': 28.035707645459887}],
#      'distance': 138,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4df105f5227193bb466e1250',
#     'name': 'Mochachos Braamfontein',
#     'location': {'lat': -26.192901099189047,
#      'lng': 28.036422326867143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192901099189047,
#        'lng': 28.036422326867143}],
#      'distance': 68,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51710052e4b07af55e7e4a06',
#     'name': 'Civic Towers',
#     'location': {'lat': -26.191366714668643,
#      'lng': 28.03717702729937,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191366714668643,
#        'lng': 28.03717702729937}],
#      'distance': 144,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d2d907c762fa14333397a64',
#     'name': 'Eat A Bite',
#     'location': {'crossStreet': 'Hoofd st',
#      'lat': -26.191016143560002,
#      'lng': 28.035696210533906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191016143560002,
#        'lng': 28.035696210533906}],
#      'distance': 153,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '558cebca498e645dd56d33e6',
#     'name': 'Vida E Caffé',
#     'location': {'address': '25 Ameshoff Street',
#      'lat': -26.190877052550437,
#      'lng': 28.035867734345995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.190877052550437,
#        'lng': 28.035867734345995}],
#      'distance': 164,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['25 Ameshoff Street', 'EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '52c18199498ea7ea7f523fb1',
#     'name': 'Edgars Active',
#     'location': {'address': 'Braamfontein',
#      'lat': -26.192573155521245,
#      'lng': 28.035753385156408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192573155521245,
#        'lng': 28.035753385156408}],
#      'distance': 52,
#      'cc': 'ZA',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Braamfontein', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1f2941735',
#       'name': 'Sporting Goods Shop',
#       'pluralName': 'Sporting Goods Shops',
#       'shortName': 'Sporting Goods',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4cc1cfd93d7fa1cdebca9a5f',
#     'name': 'Melle braam',
#     'location': {'crossStreet': 'Melle jorison',
#      'lat': -26.192283,
#      'lng': 28.036297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192283,
#        'lng': 28.036297}],
#      'distance': 10,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5920a1e11499462d62320589',
#     'name': 'Glenfidich Indpendent Bar',
#     'location': {'lat': -26.193129,
#      'lng': 28.036435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193129,
#        'lng': 28.036435}],
#      'distance': 92,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', '2001', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e3fca86aeb73139a196b50e',
#     'name': 'Vélo',
#     'location': {'address': 'Shop 2, The Grove Corner',
#      'crossStreet': 'Cnr. Juta & Melle St. Braamfontein',
#      'lat': -26.19400205909972,
#      'lng': 28.0360438655715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19400205909972,
#        'lng': 28.0360438655715}],
#      'distance': 187,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Shop 2, The Grove Corner (Cnr. Juta & Melle St. Braamfontein)',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4fd88ef3e4b04e404e149910',
#     'name': 'Hospice Wits Books',
#     'location': {'address': '17 Melle Street, Braamfontein',
#      'crossStreet': 'Juta Street',
#      'lat': -26.19410259578656,
#      'lng': 28.036199346577902,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19410259578656,
#        'lng': 28.036199346577902}],
#      'distance': 198,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['17 Melle Street, Braamfontein (Juta Street)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d114951735',
#       'name': 'Bookstore',
#       'pluralName': 'Bookstores',
#       'shortName': 'Bookstore',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '58887f2051666a2596b34b29',
#     'name': 'Emet Gyms Outdoor Training Braamfontein',
#     'location': {'lat': -26.190981,
#      'lng': 28.035531,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.190981,
#        'lng': 28.035531}],
#      'distance': 163,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4f23d25ce4b0d10dafcb6f3c',
#     'name': 'Lamunu Restaurant & Bar',
#     'location': {'address': 'Lamunu Hotel',
#      'crossStreet': '90 De Korte St. Braamfontein',
#      'lat': -26.193861518593796,
#      'lng': 28.03623936870179,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193861518593796,
#        'lng': 28.03623936870179}],
#      'distance': 171,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Lamunu Hotel (90 De Korte St. Braamfontein)',
#       'EGoli',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51e92bdf498e190fe7d597d0',
#     'name': 'The Great Dance,Braamfontein',
#     'location': {'lat': -26.192612,
#      'lng': 28.035386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192612,
#        'lng': 28.035386}],
#      'distance': 87,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1e2931735',
#       'name': 'Art Gallery',
#       'pluralName': 'Art Galleries',
#       'shortName': 'Art Gallery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d5e295f5c39b1f7aa64e849',
#     'name': 'South point',
#     'location': {'address': '46 de korte street',
#      'crossStreet': 'De beer',
#      'lat': -26.193948181392646,
#      'lng': 28.03590775654489,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.193948181392646,
#        'lng': 28.03590775654489}],
#      'distance': 183,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['46 de korte street (De beer)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4d6242c35c39b1f7edac184a',
#     'name': 'Libridge',
#     'location': {'address': '25 Ameshoff Street',
#      'lat': -26.19062835,
#      'lng': 28.03603771,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19062835,
#        'lng': 28.03603771}],
#      'distance': 189,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['25 Ameshoff Street',
#       'Braamfontein',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '561161678'},
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5768246d498e0e981e4de39f',
#     'name': 'Selgo Pharmacy Cc',
#     'location': {'address': '91 De Korte Street, Braamfontein',
#      'lat': -26.19321,
#      'lng': 28.03677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19321,
#        'lng': 28.03677}],
#      'distance': 114,
#      'postalCode': '8001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['91 De Korte Street, Braamfontein',
#       'EGoli',
#       '8001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d10f951735',
#       'name': 'Pharmacy',
#       'pluralName': 'Pharmacies',
#       'shortName': 'Pharmacy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#        'suffix': '.png'},
#       'primary': True}],
# ...
#     'hasPerk': False},
#    {'id': '513b1572e4b04f701fd50841',
#     'name': 'Gauteng Institute for Architecture (GIFA)',
#     'location': {'lat': -26.194089604586406,
#      'lng': 28.03550181667922,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194089604586406,
#        'lng': 28.03550181667922}],
#      'distance': 208,
#      'cc': 'ZA',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d198941735',
#       'name': 'College Academic Building',
#       'pluralName': 'College Academic Buildings',
#       'shortName': 'Academic Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4fc1ed77e4b089f18c33871e',
#     'name': 'SACP headquarters',
#     'location': {'address': '110 Jorissen St',
#      'lat': -26.192684173583984,
#      'lng': 28.038482666015625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192684173583984,
#        'lng': 28.038482666015625}],
#      'distance': 231,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['110 Jorissen St', 'EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d127941735',
#       'name': 'Conference Room',
#       'pluralName': 'Conference Rooms',
#       'shortName': 'Conference room',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_conferenceroom_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '53e346a9498e290e522e64e8',
#     'name': 'SPACE',
#     'location': {'address': '17 Melle Street',
#      'lat': -26.194195,
#      'lng': 28.035757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194195,
#        'lng': 28.035757}],
#      'distance': 213,
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['17 Melle Street',
#       'Braamfontein',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a3d',
#       'name': 'Advertising Agency',
#       'pluralName': 'Advertising Agencies',
#       'shortName': 'Advertising Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51d825c0498e4355506ea1e5',
#     'name': 'Starlight Express @ The Joe',
#     'location': {'lat': -26.191179087065624,
#      'lng': 28.03842341944869,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191179087065624,
#        'lng': 28.03842341944869}],
#      'distance': 256,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d137941735',
#       'name': 'Theater',
#       'pluralName': 'Theaters',
#       'shortName': 'Theater',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4ee61307775b86c405b4cde3',
#     'name': "McDonald's",
#     'location': {'address': '45 Melle St. Braamfontein',
#      'crossStreet': 'Jorissen St.',
#      'lat': -26.1928298776896,
#      'lng': 28.035784761678194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1928298776896,
#        'lng': 28.035784761678194}],
#      'distance': 70,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['45 Melle St. Braamfontein (Jorissen St.)',
#       'EGoli',
#       '2001',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '50110d53e4b0cfd7897e714d',
#     'name': '73 Juta',
#     'location': {'address': '73 Juta Street',
#      'lat': -26.194202423095703,
#      'lng': 28.035114288330078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194202423095703,
#        'lng': 28.035114288330078}],
#      'distance': 235,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['73 Juta Street', 'EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '5299d61c498e2e20a8b35f37',
#     'name': 'Stache',
#     'location': {'lat': -26.194211959838867,
#      'lng': 28.034883499145508,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194211959838867,
#        'lng': 28.034883499145508}],
#      'distance': 248,
#      'cc': 'ZA',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4cac5ac036fa6dcbfd83dd78',
#     'name': 'Sarasota Spur',
#     'location': {'address': '100 Jorissen St',
#      'lat': -26.19295126758527,
#      'lng': 28.037227392196655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19295126758527,
#        'lng': 28.037227392196655}],
#      'distance': 124,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['100 Jorissen St',
#       'Braamfontein',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '51323e57e4b07cce443cc528',
#     'name': 'The Long Bar',
#     'location': {'lat': -26.1928812573425,
#      'lng': 28.036422326867143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1928812573425,
#        'lng': 28.036422326867143}],
#      'distance': 66,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4ebbab42f5b9f8d19b3b8aa1',
#     'name': "Buyi's hair salon",
#     'location': {'address': 'Himont House',
#      'crossStreet': '80 Jorrisen St',
#      'lat': -26.1935943,
#      'lng': 28.0341713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1935943,
#        'lng': 28.0341713}],
#      'distance': 247,
#      'postalCode': '2107',
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Himont House (80 Jorrisen St)',
#       'Braamfontein',
#       '2107',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d110951735',
#       'name': 'Salon / Barbershop',
#       'pluralName': 'Salons / Barbershops',
#       'shortName': 'Salon / Barbershop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '598f1a160881583a7568354d',
#     'name': 'Arbour Square',
#     'location': {'lat': -26.194411,
#      'lng': 28.036547,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194411,
#        'lng': 28.036547}],
#      'distance': 235,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', '2001', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '598f03124940bc65f0de8064',
#     'name': 'The Black Market',
#     'location': {'lat': -26.194497,
#      'lng': 28.035904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194497,
#        'lng': 28.035904}],
#      'distance': 243,
#      'postalCode': '2001',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', '2001', 'iNingizimu Afrika']},
#     'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#       'name': 'Market',
#       'pluralName': 'Markets',
#       'shortName': 'Market',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '53871af8498e1eeb9652e132',
#     'name': 'G-10 Exclusive Wear',
#     'location': {'address': '23 Jorrisen Street',
#      'crossStreet': 'De Beer Street',
#      'lat': -26.19284536921028,
#      'lng': 28.03384780883789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19284536921028,
#        'lng': 28.03384780883789}],
#      'distance': 241,
#      'postalCode': '2000',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['23 Jorrisen Street (De Beer Street)',
#       'EGoli',
#       '2000',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e2d1d51e4cd3bc166a6900f',
#     'name': 'Jay Jays Braamfontein',
#     'location': {'lat': -26.19282532827967,
#      'lng': 28.03459795875366,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19282532827967,
#        'lng': 28.03459795875366}],
#      'distance': 169,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e5b525352b1b78b81b4aaec',
#     'name': 'Ekurhuleni Metropolitan Municipality',
#     'location': {'address': '47 van Buuren Rd',
#      'lat': -26.191391,
#      'lng': 28.035863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.191391,
#        'lng': 28.035863}],
#      'distance': 108,
#      'cc': 'ZA',
#      'city': 'Bedfordviee',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['47 van Buuren Rd',
#       'Bedfordviee',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4cc6b3fb80624688143b432f',
#     'name': 'Anat - Braamfontein',
#     'location': {'address': 'Jorissen St',
#      'crossStreet': 'Melle St',
#      'lat': -26.192311,
#      'lng': 28.036297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.192311,
#        'lng': 28.036297}],
#      'distance': 9,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['Jorissen St (Melle St)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4f69fc0ee4b0e826eba704e8',
#     'name': 'Blanc Canvas',
#     'location': {'address': '70 Juta Street',
#      'crossStreet': 'De Beers',
#      'lat': -26.19423825807531,
#      'lng': 28.03721133178798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.19423825807531,
#        'lng': 28.03721133178798}],
#      'distance': 236,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['70 Juta Street (De Beers)',
#       'EGoli',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '56974370498eb4bdddb502cc',
#     'name': 'Digify JHB',
#     'location': {'lat': -26.194334404691485,
#      'lng': 28.03493006881009,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.194334404691485,
#        'lng': 28.03493006881009}],
#      'distance': 257,
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['EGoli', 'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False},
#    {'id': '4e6f28e281dc7eb5f1eb2204',
#     'name': 'Lyceum Correspondence College - Head Office',
#     'location': {'address': '78 De Korte Street',
#      'lat': -26.1934711309387,
#      'lng': 28.03715229034424,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.1934711309387,
#        'lng': 28.03715229034424}],
#      'distance': 159,
#      'cc': 'ZA',
#      'city': 'Braamfontein',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['78 De Korte Street',
#       'Braamfontein',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d197941735',
#       'name': 'College Administrative Building',
#       'pluralName': 'College Administrative Buildings',
#       'shortName': 'Administrative Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571684877',
#     'hasPerk': False}],
#   'confident': False}}

# %% [markdown]
# # Transform the results into a dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                                                                                                                                                                                                                                    categories  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'Restaurant', 'pluralName': 'Restaurants', 'shortName': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}, 'primary': True}]
# 1  []
# 2  [{'id': '4def73e84765ae376e57713a', 'name': 'Portuguese Restaurant', 'pluralName': 'Portuguese Restaurants', 'shortName': 'Portuguese', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d10a951735', 'name': 'Bank', 'pluralName': 'Banks', 'shortName': 'Bank', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d10a951735', 'name': 'Bank', 'pluralName': 'Banks', 'shortName': 'Bank', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_', 'suffix': '.png'}, 'primary': True}]
#
#    hasPerk                        id    location.address location.cc  \
# 0  False    5147a0f8e4b0a319f5300d1e  Jorrisen Street     ZA
# 1  False    4e170754b61c2903bf0690e1  27 Stiemens Street  ZA
# 2  False    4c93463efc9a224b84fbf8f1  30 Melle Street     ZA
# 3  False    51c03298498e91717cb6965f  NaN                 ZA
# 4  False    4dbaa29a81548ee14d7ddb35  Fnb 3               ZA
#
#   location.city   location.country location.crossStreet  location.distance  \
# 0  Braamfontein  iNingizimu Afrika  NaN                  81
# 1  EGoli         iNingizimu Afrika  NaN                  46
# 2  Braamfontein  iNingizimu Afrika  NaN                  63
# 3  EGoli         iNingizimu Afrika  NaN                  54
# 4  Braamfontein  iNingizimu Afrika  NaN                  71
#
#                                   location.formattedAddress  \
# 0  [Jorrisen Street, JHB, iNingizimu Afrika]
# 1  [27 Stiemens Street, EGoli, 2017, iNingizimu Afrika]
# 2  [30 Melle Street, Braamfontein, 2000, iNingizimu Afrika]
# 3  [EGoli, iNingizimu Afrika]
# 4  [Fnb 3, Braamfontein, 2147, iNingizimu Afrika]
#
#                                                          location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': -26.192902718815258, 'lng': 28.03669676376044}]
# 1  [{'label': 'display', 'lat': -26.191903211556145, 'lng': 28.036170759341008}]
# 2  [{'label': 'display', 'lat': -26.19289137, 'lng': 28.03616438}]
# 3  [{'label': 'display', 'lat': -26.192697242953585, 'lng': 28.036542393060337}]
# 4  [{'label': 'display', 'lat': -26.192859358781185, 'lng': 28.03658813254108}]
#
#    location.lat  location.lng location.postalCode location.state  \
# 0 -26.192903     28.036697     NaN                 IGauteng
# 1 -26.191903     28.036171     2017                IGauteng
# 2 -26.192891     28.036164     2000                IGauteng
# 3 -26.192697     28.036542     NaN                 IGauteng
# 4 -26.192859     28.036588     2147                IGauteng
#
#                    name    referralId venuePage.id
# 0  Steers Braamfontein   v-1571684877  NaN
# 1  JD Group Head Office  v-1571684877  NaN
# 2  Nando's               v-1571684877  553105539
# 3  Fnb braamfontein      v-1571684877  NaN
# 4  First National Bank   v-1571684877  NaN

# %% [markdown]
# # Filter the results to provide a relevant dataframe with categories

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                               name  \
# 0    Steers Braamfontein
# 1    JD Group Head Office
# 2    Nando's
# 3    Fnb braamfontein
# 4    First National Bank
# 5    Absa Bank North City House Braamfontein
# 6    Devonshire Hotel - Braamfontein
# 7    Médecins Sans Frontières (MSF) - South Africa
# 8    JD House
# 9    Debonairs Pizza
# 10   Artivist
# 11   Clicks
# 12   Virgin Active Red Gym Braamfontein
# 13   Nino's Braamfontein
# 14   Liberty Gym
# 15   Orion
# 16   Nedbank
# 17   And Club
# 18   Once in Joburg
# 19   GALATA BAKERY&COFFEE
# 20   mochachos chicken villages
# 21   Spanners
# 22   Jormelle
# 23   R Janas TakeAway
# 24   Pick 'n Pay
# 25   Mickeys
# 26   KFC
# 27   The Alexander Theatre
# 28   34 on Melle
# 29   Standard Bank (Braamfontein)
# ..                            ...
# 160  Bannister Hotel
# 161  Amnesty International South Africa
# 162  Sumting Fresh
# 163  The Smokehouse and Grill
# 164  Puma Select
# 165  Southern Locks Salon
# 166  Total sport
# 167  Stages Restaurant
# 168  Eurotrashmusic
# 169  Frangos
# 170  Joe Burger
# 171  Gauteng Institute for Architecture (GIFA)
# 172  SACP headquarters
# 173  SPACE
# 174  Starlight Express @ The Joe
# 175  McDonald's
# 176  73 Juta
# 177  Stache
# 178  Sarasota Spur
# 179  The Long Bar
# 180  Buyi's hair salon
# 181  Arbour Square
# 182  The Black Market
# 183  G-10 Exclusive Wear
# 184  Jay Jays Braamfontein
# 185  Ekurhuleni Metropolitan Municipality
# 186  Anat - Braamfontein
# 187  Blanc Canvas
# 188  Digify JHB
# 189  Lyceum Correspondence College - Head Office
#
#                           categories  \
# 0    Restaurant
# 1    None
# 2    Portuguese Restaurant
# 3    Bank
# 4    Bank
# 5    Bank
# 6    Event Space
# 7    Office
# 8    Office
# 9    Pizza Place
# 10   Restaurant
# 11   None
# 12   Gym / Fitness Center
# 13   Breakfast Spot
# 14   Gym
# 15   None
# 16   Bank
# 17   Music Venue
# 18   Hotel
# 19   Coffee Shop
# 20   Mexican Restaurant
# 21   Burger Joint
# 22   None
# 23   Indian Restaurant
# 24   Grocery Store
# 25   Bar
# 26   Fast Food Restaurant
# 27   Theater
# 28   Diner
# 29   Bank
# ..    ...
# 160  Hotel
# 161  Coworking Space
# 162  Food Stand
# 163  Steakhouse
# 164  Clothing Store
# 165  Salon / Barbershop
# 166  Boutique
# 167  Restaurant
# 168  Music Venue
# 169  Dive Bar
# 170  Burger Joint
# 171  College Academic Building
# 172  Conference Room
# 173  Advertising Agency
# 174  Theater
# 175  Fast Food Restaurant
# 176  Building
# 177  Clothing Store
# 178  Breakfast Spot
# 179  Bar
# 180  Salon / Barbershop
# 181  Building
# 182  Market
# 183  Clothing Store
# 184  Clothing Store
# 185  Government Building
# 186  None
# 187  Coworking Space
# 188  Coworking Space
# 189  College Administrative Building
#
#                                                                 address  cc  \
# 0    Jorrisen Street                                                     ZA
# 1    27 Stiemens Street                                                  ZA
# 2    30 Melle Street                                                     ZA
# 3    NaN                                                                 ZA
# 4    Fnb 3                                                               ZA
# 5    NaN                                                                 ZA
# 6    49 Jorissen St                                                      ZA
# 7    49 Jorissen St., 3rd Floor                                          ZA
# 8    NaN                                                                 ZA
# 9    Shop 1 Jorbic House, Cnr Biccard And Jorrison Street, Braamfontein  ZA
# 10   7 Reserve Street                                                    ZA
# 11   Jorrissen Str                                                       ZA
# 12   Jorrisen Street                                                     ZA
# 13   NaN                                                                 ZA
# 14   NaN                                                                 ZA
# 15   49 Jorissen                                                         ZA
# 16   96 Jorissen Street, Braamfontein Nedbank, Johannesburg              ZA
# 17   NaN                                                                 ZA
# 18   90 De Korte Street                                                  ZA
# 19   87 Juta street Braamfontein                                         ZA
# 20   NaN                                                                 ZA
# 21   NaN                                                                 ZA
# 22   Melle Street                                                        ZA
# 23   NaN                                                                 ZA
# 24   Braamfontein Centre                                                 ZA
# 25   NaN                                                                 ZA
# 26   NaN                                                                 ZA
# 27   36 Stiemens St. Braamfontein                                        ZA
# 28   NaN                                                                 ZA
# 29   NaN                                                                 ZA
# ..   ...                                                                 ..
# 160  9 De Beer Street, Braamfountein                                     ZA
# 161  10th Floor, Braamfontein Centre, 23 Jorissen Street, Braamfontein   ZA
# 162  NaN                                                                 ZA
# 163  Cnr. Juta & De Beer Street, Braamfontein                            ZA
# 164  NaN                                                                 ZA
# 165  NaN                                                                 ZA
# 166  NaN                                                                 ZA
# 167  Joburg  Theatre                                                     ZA
# 168  NaN                                                                 ZA
# 169  NaN                                                                 ZA
# 170  Neighbor Goods Market                                               ZA
# 171  NaN                                                                 ZA
# 172  110 Jorissen St                                                     ZA
# 173  17 Melle Street                                                     ZA
# 174  NaN                                                                 ZA
# 175  45 Melle St. Braamfontein                                           ZA
# 176  73 Juta Street                                                      ZA
# 177  NaN                                                                 ZA
# 178  100 Jorissen St                                                     ZA
# 179  NaN                                                                 ZA
# 180  Himont House                                                        ZA
# 181  NaN                                                                 ZA
# 182  NaN                                                                 ZA
# 183  23 Jorrisen Street                                                  ZA
# 184  NaN                                                                 ZA
# 185  47 van Buuren Rd                                                    ZA
# 186  Jorissen St                                                         ZA
# 187  70 Juta Street                                                      ZA
# 188  NaN                                                                 ZA
# 189  78 De Korte Street                                                  ZA
#
#              city            country                              crossStreet  \
# 0    Braamfontein  iNingizimu Afrika  NaN
# 1    EGoli         iNingizimu Afrika  NaN
# 2    Braamfontein  iNingizimu Afrika  NaN
# 3    EGoli         iNingizimu Afrika  NaN
# 4    Braamfontein  iNingizimu Afrika  NaN
# 5    EGoli         iNingizimu Afrika  NaN
# 6    EGoli         iNingizimu Afrika  Melle St
# 7    EGoli         iNingizimu Afrika  Melle St.
# 8    EGoli         iNingizimu Afrika  NaN
# 9    EGoli         iNingizimu Afrika  Jorissen St
# 10   EGoli         iNingizimu Afrika  NaN
# 11   Braamfontein  iNingizimu Afrika  NaN
# 12   Johannesburg  iNingizimu Afrika  NaN
# 13   EGoli         iNingizimu Afrika  NaN
# 14   EGoli         iNingizimu Afrika  NaN
# 15   EGoli         iNingizimu Afrika  Melle
# 16   Braamfontein  iNingizimu Afrika  NaN
# 17   EGoli         iNingizimu Afrika  NaN
# 18   EGoli         iNingizimu Afrika  NaN
# 19   EGoli         iNingizimu Afrika  NaN
# 20   Braamfontein  iNingizimu Afrika  NaN
# 21   EGoli         iNingizimu Afrika  NaN
# 22   Braamfontein  iNingizimu Afrika  Jorrison
# 23   EGoli         iNingizimu Afrika  NaN
# 24   Johanessburg  iNingizimu Afrika  Cnr. Jorissen & Bertha St. Braamfontein
# 25   EGoli         iNingizimu Afrika  NaN
# 26   EGoli         iNingizimu Afrika  NaN
# 27   EGoli         iNingizimu Afrika  btwn De Beer & Melle St.
# 28   EGoli         iNingizimu Afrika  NaN
# 29   EGoli         iNingizimu Afrika  NaN
# ..     ...                       ...  ...
# 160  EGoli         iNingizimu Afrika  NaN
# 161  EGoli         iNingizimu Afrika  NaN
# 162  EGoli         iNingizimu Afrika  NaN
# 163  Braamfontein  iNingizimu Afrika  NaN
# 164  EGoli         iNingizimu Afrika  NaN
# 165  EGoli         iNingizimu Afrika  NaN
# 166  NaN           iNingizimu Afrika  NaN
# 167  EGoli         iNingizimu Afrika  NaN
# 168  NaN           iNingizimu Afrika  NaN
# 169  NaN           iNingizimu Afrika  NaN
# 170  NaN           iNingizimu Afrika  Jura Street
# 171  NaN           iNingizimu Afrika  NaN
# 172  EGoli         iNingizimu Afrika  NaN
# 173  Braamfontein  iNingizimu Afrika  NaN
# 174  EGoli         iNingizimu Afrika  NaN
# 175  EGoli         iNingizimu Afrika  Jorissen St.
# 176  EGoli         iNingizimu Afrika  NaN
# 177  NaN           iNingizimu Afrika  NaN
# 178  Braamfontein  iNingizimu Afrika  NaN
# 179  EGoli         iNingizimu Afrika  NaN
# 180  Braamfontein  iNingizimu Afrika  80 Jorrisen St
# 181  EGoli         iNingizimu Afrika  NaN
# 182  EGoli         iNingizimu Afrika  NaN
# 183  EGoli         iNingizimu Afrika  De Beer Street
# 184  EGoli         iNingizimu Afrika  NaN
# 185  Bedfordviee   iNingizimu Afrika  NaN
# 186  EGoli         iNingizimu Afrika  Melle St
# 187  EGoli         iNingizimu Afrika  De Beers
# 188  EGoli         iNingizimu Afrika  NaN
# 189  Braamfontein  iNingizimu Afrika  NaN
#
#      distance  \
# 0    81
# 1    46
# 2    63
# 3    54
# 4    71
# 5    42
# 6    45
# 7    60
# 8    40
# 9    62
# 10   112
# 11   13
# 12   115
# 13   87
# 14   176
# 15   61
# 16   453
# 17   144
# 18   172
# 19   182
# 20   24
# 21   110
# 22   4
# 23   148
# 24   185
# 25   45
# 26   141
# 27   119
# 28   69
# 29   161
# ..   ...
# 160  227
# 161  235
# 162  259
# 163  266
# 164  254
# 165  93
# 166  54
# 167  229
# 168  256
# 169  242
# 170  244
# 171  208
# 172  231
# 173  213
# 174  256
# 175  70
# 176  235
# 177  248
# 178  124
# 179  66
# 180  247
# 181  235
# 182  243
# 183  241
# 184  169
# 185  108
# 186  9
# 187  236
# 188  257
# 189  159
#
#                                                                                                        formattedAddress  \
# 0    [Jorrisen Street, JHB, iNingizimu Afrika]
# 1    [27 Stiemens Street, EGoli, 2017, iNingizimu Afrika]
# 2    [30 Melle Street, Braamfontein, 2000, iNingizimu Afrika]
# 3    [EGoli, iNingizimu Afrika]
# 4    [Fnb 3, Braamfontein, 2147, iNingizimu Afrika]
# 5    [EGoli, iNingizimu Afrika]
# 6    [49 Jorissen St (Melle St), EGoli, 2017, iNingizimu Afrika]
# 7    [49 Jorissen St., 3rd Floor (Melle St.), EGoli, 2017, iNingizimu Afrika]
# 8    [EGoli, iNingizimu Afrika]
# 9    [Shop 1 Jorbic House, Cnr Biccard And Jorrison Street, Braamfontein (Jorissen St), EGoli, 2000, iNingizimu Afrika]
# 10   [7 Reserve Street, EGoli, 2001, iNingizimu Afrika]
# 11   [Jorrissen Str, Braamfontein, iNingizimu Afrika]
# 12   [Jorrisen Street, Johannesburg, 2000, iNingizimu Afrika]
# 13   [EGoli, iNingizimu Afrika]
# 14   [EGoli, iNingizimu Afrika]
# 15   [49 Jorissen (Melle), EGoli, iNingizimu Afrika]
# 16   [96 Jorissen Street, Braamfontein Nedbank, Johannesburg, Braamfontein, 2000, iNingizimu Afrika]
# 17   [EGoli, iNingizimu Afrika]
# 18   [90 De Korte Street, EGoli, 2001, iNingizimu Afrika]
# 19   [87 Juta street Braamfontein, EGoli, iNingizimu Afrika]
# 20   [Braamfontein, iNingizimu Afrika]
# 21   [EGoli, 2001, iNingizimu Afrika]
# 22   [Melle Street (Jorrison), Braamfontein, Johannesburg, 2001, iNingizimu Afrika]
# 23   [EGoli, iNingizimu Afrika]
# 24   [Braamfontein Centre (Cnr. Jorissen & Bertha St. Braamfontein), Johanessburg, 2001, iNingizimu Afrika]
# 25   [EGoli, iNingizimu Afrika]
# 26   [EGoli, iNingizimu Afrika]
# 27   [36 Stiemens St. Braamfontein (btwn De Beer & Melle St.), EGoli, 2001, iNingizimu Afrika]
# 28   [EGoli, iNingizimu Afrika]
# 29   [EGoli, iNingizimu Afrika]
# ..                          ...
# 160  [9 De Beer Street, Braamfountein, EGoli, reservations, iNingizimu Afrika]
# 161  [10th Floor, Braamfontein Centre, 23 Jorissen Street, Braamfontein, EGoli, iNingizimu Afrika]
# 162  [EGoli, iNingizimu Afrika]
# 163  [Cnr. Juta & De Beer Street, Braamfontein, Braamfontein, 2001, iNingizimu Afrika]
# 164  [EGoli, iNingizimu Afrika]
# 165  [EGoli, iNingizimu Afrika]
# 166  [iNingizimu Afrika]
# 167  [Joburg  Theatre, EGoli, iNingizimu Afrika]
# 168  [iNingizimu Afrika]
# 169  [iNingizimu Afrika]
# 170  [Neighbor Goods Market (Jura Street), iNingizimu Afrika]
# 171  [iNingizimu Afrika]
# 172  [110 Jorissen St, EGoli, iNingizimu Afrika]
# 173  [17 Melle Street, Braamfontein, iNingizimu Afrika]
# 174  [EGoli, iNingizimu Afrika]
# 175  [45 Melle St. Braamfontein (Jorissen St.), EGoli, 2001, iNingizimu Afrika]
# 176  [73 Juta Street, EGoli, iNingizimu Afrika]
# 177  [iNingizimu Afrika]
# 178  [100 Jorissen St, Braamfontein, 2000, iNingizimu Afrika]
# 179  [EGoli, iNingizimu Afrika]
# 180  [Himont House (80 Jorrisen St), Braamfontein, 2107, iNingizimu Afrika]
# 181  [EGoli, 2001, iNingizimu Afrika]
# 182  [EGoli, 2001, iNingizimu Afrika]
# 183  [23 Jorrisen Street (De Beer Street), EGoli, 2000, iNingizimu Afrika]
# 184  [EGoli, iNingizimu Afrika]
# 185  [47 van Buuren Rd, Bedfordviee, iNingizimu Afrika]
# 186  [Jorissen St (Melle St), EGoli, iNingizimu Afrika]
# 187  [70 Juta Street (De Beers), EGoli, iNingizimu Afrika]
# 188  [EGoli, iNingizimu Afrika]
# 189  [78 De Korte Street, Braamfontein, iNingizimu Afrika]
#
#                                                                     labeledLatLngs  \
# 0    [{'label': 'display', 'lat': -26.192902718815258, 'lng': 28.03669676376044}]
# 1    [{'label': 'display', 'lat': -26.191903211556145, 'lng': 28.036170759341008}]
# 2    [{'label': 'display', 'lat': -26.19289137, 'lng': 28.03616438}]
# 3    [{'label': 'display', 'lat': -26.192697242953585, 'lng': 28.036542393060337}]
# 4    [{'label': 'display', 'lat': -26.192859358781185, 'lng': 28.03658813254108}]
# 5    [{'label': 'display', 'lat': -26.191963070366253, 'lng': 28.03633656525069}]
# 6    [{'label': 'display', 'lat': -26.192708967540018, 'lng': 28.036050692895625}]
# 7    [{'label': 'display', 'lat': -26.192847919994563, 'lng': 28.036354670459858}]
# 8    [{'label': 'display', 'lat': -26.19195432570274, 'lng': 28.03620093750918}]
# 9    [{'label': 'display', 'lat': -26.192520325742947, 'lng': 28.036788163634924}]
# 10   [{'label': 'display', 'lat': -26.193171, 'lng': 28.036803}]
# 11   [{'label': 'display', 'lat': -26.19222697704686, 'lng': 28.036113584853368}]
# 12   [{'label': 'display', 'lat': -26.193058, 'lng': 28.035387}]
# 13   [{'label': 'display', 'lat': -26.191708781193977, 'lng': 28.03564251120332}]
# 14   [{'label': 'display', 'lat': -26.19104942971893, 'lng': 28.03514161573696}]
# 15   [{'label': 'display', 'lat': -26.1927561836301, 'lng': 28.036573071967577}]
# 16   [{'label': 'display', 'lat': -26.193222045898438, 'lng': 28.031766891479492}]
# 17   [{'label': 'display', 'lat': -26.19210178991824, 'lng': 28.034775696568722}]
# 18   [{'label': 'display', 'lat': -26.193871730809743, 'lng': 28.03624931206623}]
# 19   [{'label': 'display', 'lat': -26.193957003238783, 'lng': 28.03613924076584}]
# 20   [{'label': 'display', 'lat': -26.192287816766783, 'lng': 28.035953496189688}]
# 21   [{'label': 'display', 'lat': -26.191561, 'lng': 28.035482}]
# 22   [{'label': 'display', 'lat': -26.1923625, 'lng': 28.0361847}]
# 23   [{'label': 'display', 'lat': -26.19365692138672, 'lng': 28.036191940307617}]
# 24   [{'label': 'display', 'lat': -26.192794878836263, 'lng': 28.03442121165301}]
# 25   [{'label': 'display', 'lat': -26.192218310915507, 'lng': 28.035753385156408}]
# 26   [{'label': 'display', 'lat': -26.19338460735376, 'lng': 28.03697829689719}]
# 27   [{'label': 'display', 'lat': -26.192280862969564, 'lng': 28.035004689322285}]
# 28   [{'label': 'display', 'lat': -26.192792011392836, 'lng': 28.035741950233387}]
# 29   [{'label': 'display', 'lat': -26.192947921103233, 'lng': 28.034740756315088}]
# ..                                                                             ...
# 160  [{'label': 'display', 'lat': -26.19400150748047, 'lng': 28.034907198856903}]
# 161  [{'label': 'display', 'lat': -26.1934711309387, 'lng': 28.034223318099976}]
# 162  [{'label': 'display', 'lat': -26.19438, 'lng': 28.034983}]
# 163  [{'label': 'display', 'lat': -26.194439528911936, 'lng': 28.034946506490588}]
# 164  [{'label': 'display', 'lat': -26.194549942357227, 'lng': 28.035633318427816}]
# 165  [{'label': 'display', 'lat': -26.193116310230092, 'lng': 28.03590775654489}]
# 166  [{'label': 'display', 'lat': -26.1922236943999, 'lng': 28.03673106834217}]
# 167  [{'label': 'display', 'lat': -26.192688769098325, 'lng': 28.03846344106942}]
# 168  [{'label': 'display', 'lat': -26.194255, 'lng': 28.034803}]
# 169  [{'label': 'display', 'lat': -26.192235, 'lng': 28.033772}]
# 170  [{'label': 'display', 'lat': -26.194176, 'lng': 28.034891}]
# 171  [{'label': 'display', 'lat': -26.194089604586406, 'lng': 28.03550181667922}]
# 172  [{'label': 'display', 'lat': -26.192684173583984, 'lng': 28.038482666015625}]
# 173  [{'label': 'display', 'lat': -26.194195, 'lng': 28.035757}]
# 174  [{'label': 'display', 'lat': -26.191179087065624, 'lng': 28.03842341944869}]
# 175  [{'label': 'display', 'lat': -26.1928298776896, 'lng': 28.035784761678194}]
# 176  [{'label': 'display', 'lat': -26.194202423095703, 'lng': 28.035114288330078}]
# 177  [{'label': 'display', 'lat': -26.194211959838867, 'lng': 28.034883499145508}]
# 178  [{'label': 'display', 'lat': -26.19295126758527, 'lng': 28.037227392196655}]
# 179  [{'label': 'display', 'lat': -26.1928812573425, 'lng': 28.036422326867143}]
# 180  [{'label': 'display', 'lat': -26.1935943, 'lng': 28.0341713}]
# 181  [{'label': 'display', 'lat': -26.194411, 'lng': 28.036547}]
# 182  [{'label': 'display', 'lat': -26.194497, 'lng': 28.035904}]
# 183  [{'label': 'display', 'lat': -26.19284536921028, 'lng': 28.03384780883789}]
# 184  [{'label': 'display', 'lat': -26.19282532827967, 'lng': 28.03459795875366}]
# 185  [{'label': 'display', 'lat': -26.191391, 'lng': 28.035863}]
# 186  [{'label': 'display', 'lat': -26.192311, 'lng': 28.036297}]
# 187  [{'label': 'display', 'lat': -26.19423825807531, 'lng': 28.03721133178798}]
# 188  [{'label': 'display', 'lat': -26.194334404691485, 'lng': 28.03493006881009}]
# 189  [{'label': 'display', 'lat': -26.1934711309387, 'lng': 28.03715229034424}]
#
#            lat        lng    postalCode     state                        id
# 0   -26.192903  28.036697  NaN           IGauteng  5147a0f8e4b0a319f5300d1e
# 1   -26.191903  28.036171  2017          IGauteng  4e170754b61c2903bf0690e1
# 2   -26.192891  28.036164  2000          IGauteng  4c93463efc9a224b84fbf8f1
# 3   -26.192697  28.036542  NaN           IGauteng  51c03298498e91717cb6965f
# 4   -26.192859  28.036588  2147          IGauteng  4dbaa29a81548ee14d7ddb35
# 5   -26.191963  28.036337  NaN           IGauteng  4d746dc39b28224b1dddd50f
# 6   -26.192709  28.036051  2017          IGauteng  4d01e7686b0c236af79aaba2
# 7   -26.192848  28.036355  2017          IGauteng  4c921fbc7f3b8cfa5d52a21e
# 8   -26.191954  28.036201  NaN           IGauteng  4c0893f7009a0f47e068e6bf
# 9   -26.192520  28.036788  2000          IGauteng  4d1dca18dd6a236a5f772038
# 10  -26.193171  28.036803  2001          IGauteng  5b50cf5e3260db001c36dd01
# 11  -26.192227  28.036114  NaN           IGauteng  533130d011d271112c08344c
# 12  -26.193058  28.035387  2000          Gaugeng   582b198b26d44f0d228af768
# 13  -26.191709  28.035643  NaN           IGauteng  4c6382cf58810f474e0f0a1e
# 14  -26.191049  28.035142  NaN           IGauteng  4f732cdee4b00743451232f9
# 15  -26.192756  28.036573  NaN           IGauteng  4e364a1cd4c063434836ecf1
# 16  -26.193222  28.031767  2000          IGauteng  5200c97c498e5f4767c778e9
# 17  -26.192102  28.034776  NaN           IGauteng  536e8401498e080bd9bee363
# 18  -26.193872  28.036249  2001          IGauteng  57d27c3c498ec65fd817d109
# 19  -26.193957  28.036139  NaN           IGauteng  58a66e0619b1ad18d7d89f9e
# 20  -26.192288  28.035953  NaN           IGauteng  52fcfd93498e5ba0aeb20785
# 21  -26.191561  28.035482  2001          IGauteng  59845ae6b9a5a866d56cf9b9
# 22  -26.192363  28.036185  2001          IGauteng  4e6746b8a8098026753e00cc
# 23  -26.193657  28.036192  NaN           IGauteng  52a1af4811d2606567ab62cb
# 24  -26.192795  28.034421  2001          IGauteng  4d46b29614aa8cfab25d7f3d
# 25  -26.192218  28.035753  NaN           IGauteng  53525cb111d2993499d8f9e2
# 26  -26.193385  28.036978  NaN           IGauteng  4e39395c6284250071bae2c9
# 27  -26.192281  28.035005  2001          IGauteng  4b8975c6f964a520543832e3
# 28  -26.192792  28.035742  NaN           IGauteng  53c15e0f498ed6ec6b7968ce
# 29  -26.192948  28.034741  NaN           IGauteng  4d47f79f847e6dcb3d5c99c4
# ..         ...        ...  ...                ...                       ...
# 160 -26.194002  28.034907  reservations  IGauteng  522478a811d2ebf3de588043
# 161 -26.193471  28.034223  NaN           IGauteng  4f1569400039f9a1c457c16b
# 162 -26.194380  28.034983  NaN           IGauteng  584bc6538b0ebb3d3b429eb0
# 163 -26.194440  28.034947  2001          IGauteng  52971b26498e63e129181aaa
# 164 -26.194550  28.035633  NaN           IGauteng  53dcb446498eebb10a7eb4f3
# 165 -26.193116  28.035908  NaN           IGauteng  51308357e4b0835c5653fe32
# 166 -26.192224  28.036731  NaN           NaN       518f5a53498e5019726875ec
# 167 -26.192689  28.038463  NaN           IGauteng  51d9bd1e498e95963ef1fb8c
# 168 -26.194255  28.034803  NaN           NaN       4fcd1063e4b0565b1070ee27
# 169 -26.192235  28.033772  NaN           NaN       50732879e4b088fde8d97a2a
# 170 -26.194176  28.034891  NaN           NaN       4f48b95ae4b0d6374158230f
# 171 -26.194090  28.035502  NaN           NaN       513b1572e4b04f701fd50841
# 172 -26.192684  28.038483  NaN           IGauteng  4fc1ed77e4b089f18c33871e
# 173 -26.194195  28.035757  NaN           IGauteng  53e346a9498e290e522e64e8
# 174 -26.191179  28.038423  NaN           IGauteng  51d825c0498e4355506ea1e5
# 175 -26.192830  28.035785  2001          IGauteng  4ee61307775b86c405b4cde3
# 176 -26.194202  28.035114  NaN           IGauteng  50110d53e4b0cfd7897e714d
# 177 -26.194212  28.034883  NaN           NaN       5299d61c498e2e20a8b35f37
# 178 -26.192951  28.037227  2000          IGauteng  4cac5ac036fa6dcbfd83dd78
# 179 -26.192881  28.036422  NaN           IGauteng  51323e57e4b07cce443cc528
# 180 -26.193594  28.034171  2107          IGauteng  4ebbab42f5b9f8d19b3b8aa1
# 181 -26.194411  28.036547  2001          IGauteng  598f1a160881583a7568354d
# 182 -26.194497  28.035904  2001          IGauteng  598f03124940bc65f0de8064
# 183 -26.192845  28.033848  2000          IGauteng  53871af8498e1eeb9652e132
# 184 -26.192825  28.034598  NaN           IGauteng  4e2d1d51e4cd3bc166a6900f
# 185 -26.191391  28.035863  NaN           IGauteng  4e5b525352b1b78b81b4aaec
# 186 -26.192311  28.036297  NaN           IGauteng  4cc6b3fb80624688143b432f
# 187 -26.194238  28.037211  NaN           IGauteng  4f69fc0ee4b0e826eba704e8
# 188 -26.194334  28.034930  NaN           IGauteng  56974370498eb4bdddb502cc
# 189 -26.193471  28.037152  NaN           IGauteng  4e6f28e281dc7eb5f1eb2204
#
# [190 rows x 15 columns]

# %% [markdown]
# # Display the Points of Interest on a Map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel


folium.features.CircleMarker(
    [latitude, longitude],
    radius=50,
    color='red',
    popup='Johannesburg',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.1
).add_to(venues_map)

# add the Coffee SHops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Perform a count of the returned values

# %%
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.name.count()
# Out:
# 35

# %%
dataframe = json_normalize(venues)

# %% [markdown]
# # Group and count the duplicates

# %%
df=dataframe
df.name.value_counts()
# Out:
# Seattle Coffee Company                                                                               3
# Kaldi's Coffee                                                                                       2
# Trams Coffee Shop                                                                                    1
# Hollard Coffee Shop                                                                                  1
# Time Out Cafe                                                                                        1
# Coffee Brew                                                                                          1
# Urban Coffee                                                                                         1
# Coffee World                                                                                         1
# Cramers Coffee                                                                                       1
# Rush Coffee House                                                                                    1
# Indian Coffee House                                                                                  1
# Okoa Coffee Co.                                                                                      1
# Woolworths Coffee Shop                                                                               1
# @The coffee shop                                                                                     1
# Greenberry Frozen Yogurt And Coffee Bar                                                              1
# GALATA BAKERY&COFFEE                                                                                 1
# Pino's Italian Coffee Shop                                                                           1
# Nilah's Coffee Shop & Bakery, Trocadero Centre, Observatory, Johannesburg/ Jozi, South Africa/ ZA    1
# Double Shot Tea & Coffee                                                                             1
# Coffee shop                                                                                          1
# Bean There Coffee                                                                                    1
# Firebird Coffee                                                                                      1
# Indaba Coffee Shop                                                                                   1
# Shape Coffee shop & Event Studio                                                                     1
# Craft Coffee Newtown                                                                                 1
# Bean There Coffee Roastery                                                                           1
# Father Coffee                                                                                        1
# Tarantino's Coffee Co                                                                                1
# chaywa coffee                                                                                        1
# Motherland Coffee Company                                                                            1
# Hei Coffee                                                                                           1
# Nilde's Coffee Shop                                                                                  1
# Name: name, dtype: int64

# %% [markdown]
# # Count the number of different cofee shops present in the area

# %%
df['name'].nunique()
# Out:
# 32

# %% [markdown]
# # Get Take a clsoer look at Seattle coffee and understand their positioning

# %%
venue_id = '4bbcc204f57ba5935631adb9' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url

result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '4bbcc204f57ba5935631adb9',
#  'name': 'Seattle Coffee Company',
#  'contact': {'phone': '+27116466455', 'formattedPhone': '+27 11 646 6455'},
#  'location': {'address': 'Killarney Mall',
#   'lat': -26.167016056676076,
#   'lng': 28.05434940289756,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -26.167016056676076,
#     'lng': 28.05434940289756}],
#   'cc': 'ZA',
#   'city': 'Killarney',
#   'state': 'IGauteng',
#   'country': 'iNingizimu Afrika',
#   'formattedAddress': ['Killarney Mall', 'Killarney', 'iNingizimu Afrika']},
#  'canonicalUrl': 'https://foursquare.com/v/seattle-coffee-company/4bbcc204f57ba5935631adb9',
#  'categories': [{'id': '4bf58dd8d48988d1e0931735',
#    'name': 'Coffee Shop',
#    'pluralName': 'Coffee Shops',
#    'shortName': 'Coffee Shop',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 8},
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 2,
#   'groups': [{'type': 'others',
#     'count': 2,
#     'items': [{'id': '125403772',
#       'firstName': 'Anusha',
#       'lastName': 'Lalloo',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/blank_girl.png',
#        'default': True}},
#      {'id': '12071308',
#       'firstName': 'Mariza',
#       'lastName': 'O',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/12071308-HCUY1FO3KNHA1ZAL.jpg'}}]}],
#   'summary': '2 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.1,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 9,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 16,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 16,
#     'items': [{'id': '5108a56be4b028437bc8c337',
#       'createdAt': 1359521131,
#       'source': {'name': 'Foursquare for iOS',
#        'url': 'https://foursquare.com/download/#/iphone'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/39474036_bxj1pEvOpyUHwsdvK9JOoaxW3UMFYlrXZIwf4hUvd78.jpg',
#       'width': 480,
#       'height': 720,
#       'user': {'id': '39474036',
#        'firstName': 'Desmond',
#        'lastName': 'Oxford',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/39474036-3ZAJYCYJO5TSB10J.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1270661636,
#  'tips': {'count': 8,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 8,
#     'items': [{'id': '51c47c1c498efa7841bc6e8a',
#       'createdAt': 1371831324,
#       'text': "The coffee's good, but not as nice as Cramers in the Jhb CBD!",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/51c47c1c498efa7841bc6e8a',
#       'lang': 'en',
#       'likes': {'count': 1,
#        'groups': [{'type': 'others',
#          'count': 1,
#          'items': [{'id': '63638114',
#            'firstName': 'Lekunutu Joshua',
#            'lastName': 'Thobatsi',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/HFNKXDZLLHAQLRDU.jpg'}}]}],
#        'summary': '1 like'},
#       'logView': True,
#       'agreeCount': 1,
#       'disagreeCount': 0,
#       'todo': {'count': 1},
#       'user': {'id': '21511036',
#        'firstName': 'Afzul',
#        'lastName': 'Soobedaar',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/X05JAMTSXYZSEU3F.jpg'}}}]}]},
#  'shortUrl': 'http://4sq.com/bBpISu',
#  'timeZone': 'Africa/Johannesburg',
#  'listed': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 2,
#     'items': [{'id': '4ee9c2605c5c0575fab447f6',
#       'name': 'My Favourite Places',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '2783258',
#        'firstName': 'SarahTheBlue',
#        'lastName': '†',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/2783258-1DFMH4JHVOKLQB0O.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/2783258/list/my-favourite-places-1',
#       'canonicalUrl': 'https://foursquare.com/user/2783258/list/my-favourite-places-1',
#       'createdAt': 1323942496,
#       'updatedAt': 1406908369,
#       'followers': {'count': 4},
#       'listItems': {'count': 42,
#        'items': [{'id': 'v4bbcc204f57ba5935631adb9',
#          'createdAt': 1339762614}]}},
#      {'id': '4e4fd7571fc7e04d29e308a6',
#       'name': 'All-time favorites in South Africa',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '5805159',
#        'firstName': 'Prasanna',
#        'lastName': 'Sarma',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/5805159-IXL4HKWWCNBSNOO3.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/greatprasi/list/alltime-favorites-in-south-africa',
#       'canonicalUrl': 'https://foursquare.com/greatprasi/list/alltime-favorites-in-south-africa',
#       'createdAt': 1313855319,
#       'updatedAt': 1381823067,
#       'followers': {'count': 3},
#       'listItems': {'count': 20,
#        'items': [{'id': 'v4bbcc204f57ba5935631adb9',
#          'createdAt': 1313855319}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '10:00 AM–11:00 AM'},
#      {'renderedTime': '1:00 PM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–Noon'},
#      {'renderedTime': '2:00 PM–5:00 PM'},
#      {'renderedTime': '7:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '6:00 AM–7:00 AM'},
#      {'renderedTime': '9:00 AM–6:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '8:00 AM–5:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '9:00 AM–4:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '10:00 AM–3:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '4b7fb847f964a5208c3a30e3',
#   'name': 'Killarney Mall',
#   'location': {'address': '60 Riviera Rd',
#    'lat': -26.16668321520859,
#    'lng': 28.054299856787463,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': -26.16668321520859,
#      'lng': 28.054299856787463}],
#    'postalCode': '2193',
#    'cc': 'ZA',
#    'city': 'EGoli',
#    'state': 'IGauteng',
#    'country': 'iNingizimu Afrika',
#    'formattedAddress': ['60 Riviera Rd',
#     'EGoli',
#     '2193',
#     'iNingizimu Afrika']},
#   'categories': [{'id': '4bf58dd8d48988d1fd941735',
#     'name': 'Shopping Mall',
#     'pluralName': 'Shopping Malls',
#     'shortName': 'Mall',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '49674240'}},
#  'hierarchy': [{'name': 'Killarney Mall',
#    'lang': 'en',
#    'id': '4b7fb847f964a5208c3a30e3',
#    'canonicalUrl': 'https://foursquare.com/v/killarney-mall/4b7fb847f964a5208c3a30e3'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price',
#       'displayValue': '$',
#       'priceTier': 1}]}]},
#  'bestPhoto': {'id': '5108a56be4b028437bc8c337',
#   'createdAt': 1359521131,
#   'source': {'name': 'Foursquare for iOS',
#    'url': 'https://foursquare.com/download/#/iphone'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/39474036_bxj1pEvOpyUHwsdvK9JOoaxW3UMFYlrXZIwf4hUvd78.jpg',
#   'width': 480,
#   'height': 720,
#   'visibility': 'public'}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.1

# %%
result['response']['venue']['tips']['count']
# Out:
# 8

# %%
## Ecco Tips
limit = 5 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dadfc79a4b51b66a7fb197c'},
#  'response': {'tips': {'count': 8,
#    'items': [{'id': '5053369de4b012cb815325e4',
#      'createdAt': 1347630749,
#      'text': "they've got ice~~ if u want a nice ice latte not a blend jus ask to add ice and wallah! ice latte; vanilla my fave!",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5053369de4b012cb815325e4',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '34510548',
#       'firstName': 'Colette',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/ILKOXHT0CCWS2T0P.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                   text  \
# 0  they've got ice~~ if u want a nice ice latte not a blend jus ask to add ice and wallah! ice latte; vanilla my fave!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              5053369de4b012cb815325e4  Colette
#
#    user.lastName user.gender   user.id
# 0 NaN             female      34510548

# %% [markdown]
# # We notice that the data points for coffee shops are clustered around the Braamfontein area.  Lets explore this...
