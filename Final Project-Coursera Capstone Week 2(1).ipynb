# %% [markdown]
# # Import Python Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 

from bs4 import BeautifulSoup
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2019.9.11  |       hecc5488_0         144 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %% [markdown]
# # Connect to the Foursquare API

# %%
CLIENT_ID = 'ZKWH10LSBTKPCOFAXZ3VB5SF1310UBUMSTMYFBAAP34OJCWC' # your Foursquare ID
CLIENT_SECRET = 'XBURRWEJJNBPOUE1MDWWRYRIZPRFIWC50A4FIUO1QNQOSROC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 500
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: ZKWH10LSBTKPCOFAXZ3VB5SF1310UBUMSTMYFBAAP34OJCWC
# CLIENT_SECRET:XBURRWEJJNBPOUE1MDWWRYRIZPRFIWC50A4FIUO1QNQOSROC

# %% [markdown]
# # Use Geolocator to get the Latitude and Longitude of Johannesburg

# %%
address = 'Johannesburg, South Africa'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -26.205 28.049722

# %% [markdown]
# # Search for Coffee in a given radius

# %%
search_query = 'coffee'
radius = 4000
print(search_query + ' .... OK!')

url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url

results = requests.get(url).json()
results
# Out:
# coffee .... OK!
# {'meta': {'code': 200, 'requestId': '5dadf6c5e97dfb0039679aab'},
#  'response': {'venues': [{'id': '4c73ac6bad69b60c569c86b9',
#     'name': 'Cramers Coffee',
#     'location': {'address': '17 Harrison St. Marshalltown',
#      'crossStreet': 'at Main St.',
#      'lat': -26.20695586420149,
#      'lng': 28.040580052466318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -26.20695586420149,
#        'lng': 28.040580052466318}],
#      'distance': 938,
#      'postalCode': '2094',
#      'cc': 'ZA',
#      'city': 'EGoli',
#      'state': 'IGauteng',
#      'country': 'iNingizimu Afrika',
#      'formattedAddress': ['17 Harrison St. Marshalltown (at Main St.)',
#       'EGoli',
#       '2094',
#       'iNingizimu Afrika']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
# ...

# %% [markdown]
# # Transform the results into a dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...    False
# 4                                                 []    False
#
#                          id                   location.address location.cc  \
# 0  4c73ac6bad69b60c569c86b9       17 Harrison St. Marshalltown          ZA
# 1  4d75c4157fe3224b2571948a                     Pritchard Str.          ZA
# 2  4e23d2fe628469a5742e0bd9  1 Central Place,Jeppe St. Newtown          ZA
# 3  54c1bbc8498e684f5ac99c93                      Interchange21          ZA
# 4  4e4241ad52b18686a81d59d2                         Fox Street          ZA
#
#   location.city   location.country  \
# 0         EGoli  iNingizimu Afrika
# 1         EGoli  iNingizimu Afrika
# ...

# %% [markdown]
# # Filter the results to provide a relevant dataframe with categories

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                                      Cramers Coffee            Coffee Shop
# 1                                 Nilde's Coffee Shop                   Café
# 2                                      Kaldi's Coffee            Coffee Shop
# 3                                        Coffee World                 Bakery
# 4                                        Urban Coffee                   None
# 5                            Double Shot Tea & Coffee            Coffee Shop
# 6                    Shape Coffee shop & Event Studio  Performing Arts Venue
# 7   Nilah's Coffee Shop & Bakery, Trocadero Centre...                   None
# 8                                   Rush Coffee House            Coffee Shop
# 9                                     Firebird Coffee            Coffee Shop
# 10                              Tarantino's Coffee Co            Coffee Shop
# ...

# %% [markdown]
# # Display the Points of Interest on a Map

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=50,
    color='red',
    popup='Johannesburg',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.1
).add_to(venues_map)

# add the Coffee SHops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Perform a count of the returned values

# %%
# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.name.count()
# Out:
# 35

# %%
dataframe = json_normalize(venues)

# %% [markdown]
# # Group and count the duplicates

# %%
df=dataframe
df.name.value_counts()
# Out:
# Seattle Coffee Company                                                                               3
# Kaldi's Coffee                                                                                       2
# Trams Coffee Shop                                                                                    1
# Hollard Coffee Shop                                                                                  1
# Time Out Cafe                                                                                        1
# Coffee Brew                                                                                          1
# Urban Coffee                                                                                         1
# Coffee World                                                                                         1
# Cramers Coffee                                                                                       1
# ...

# %% [markdown]
# # Count the number of different cofee shops present in the area

# %%
df['name'].nunique()
# Out:
# 32

# %% [markdown]
# # Get Take a clsoer look at Seattle coffee and understand their positioning

# %%
venue_id = '4bbcc204f57ba5935631adb9' 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url

result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto'])
# {'id': '4bbcc204f57ba5935631adb9',
#  'name': 'Seattle Coffee Company',
#  'contact': {'phone': '+27116466455', 'formattedPhone': '+27 11 646 6455'},
#  'location': {'address': 'Killarney Mall',
#   'lat': -26.167016056676076,
#   'lng': 28.05434940289756,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -26.167016056676076,
#     'lng': 28.05434940289756}],
#   'cc': 'ZA',
#   'city': 'Killarney',
#   'state': 'IGauteng',
#   'country': 'iNingizimu Afrika',
#   'formattedAddress': ['Killarney Mall', 'Killarney', 'iNingizimu Afrika']},
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.1

# %%
result['response']['venue']['tips']['count']
# Out:
# 8

# %%
## Ecco Tips
limit = 5 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dadfc79a4b51b66a7fb197c'},
#  'response': {'tips': {'count': 8,
#    'items': [{'id': '5053369de4b012cb815325e4',
#      'createdAt': 1347630749,
#      'text': "they've got ice~~ if u want a nice ice latte not a blend jus ask to add ice and wallah! ice latte; vanilla my fave!",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5053369de4b012cb815325e4',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '34510548',
#       'firstName': 'Colette',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/ILKOXHT0CCWS2T0P.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                   text  \
# 0  they've got ice~~ if u want a nice ice latte not a blend jus ask to add ice and wallah! ice latte; vanilla my fave!
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              5053369de4b012cb815325e4  Colette
#
#    user.lastName user.gender   user.id
# 0 NaN             female      34510548

# %% [markdown]
# # We notice that the data points for coffee shops are clustered around the Braamfontein area.  Lets explore this...
